# %% [markdown]
# # Khayr Aggregator – Notebook Draft
#
# Exploring initial logic for scraping, OCR, and data structuring.

# %%
# Import necessary libraries
import pandas as pd
import pytesseract
from PIL import Image
import re

# %%
# Example OCR on event poster (image must be in same folder)
# image = Image.open('poster.jpg')
# text = pytesseract.image_to_string(image)
# print(text)
