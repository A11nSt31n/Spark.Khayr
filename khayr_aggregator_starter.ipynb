# %% [markdown]
# # Khayr Aggregator – Notebook Draft
#
# Exploring initial logic for scraping, OCR, and data structuring.

# %%
# Import necessary libraries
import pandas as pd
import pytesseract
from PIL import Image
import re
import os

# %%
# Define function to extract text from all images in a folder
def extract_text_from_images(folder_path):
    extracted_data = []
    for filename in os.listdir(folder_path):
        if filename.endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(folder_path, filename)
            image = Image.open(image_path)
            text = pytesseract.image_to_string(image)
            extracted_data.append({'filename': filename, 'text': text})
    return pd.DataFrame(extracted_data)

# %%
# Example usage (update 'event_posters' to your folder name)
# df = extract_text_from_images('event_posters')
# df.head()

# %% [markdown]
# ## Next Steps:
# - Use regex to extract event date, time, venue, and price from OCR text
# - Categorize events by tags (e.g. Ladies only, Youth, Volunteer)
# - Output cleaned dataset to CSV or upload to a cloud bucket
# - Schedule automated parsing weekly using cron/Azure functions
